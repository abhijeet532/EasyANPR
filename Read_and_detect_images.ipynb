# %%
import cv2    
import time
cpt = 0
maxFrames = 120 # if you want 5 frames only.
count=500

count=0
cap=cv2.VideoCapture('Traffic Control CCTV.mp4')
while cpt < maxFrames:
    ret, frame = cap.read()
    if not ret:
        break
    count += 1
    if count % 3 != 0:
        continue
    frame=cv2.resize(frame,(1080,500))
    cv2.imshow("test window", frame) # show image in window
    cv2.imwrite(f"C:\\Users\\Abhijeet Tripathi\\Downloads\\new_image_{count}.jpg", frame)
    count+=1

    time.sleep(0.01)
    cpt += 1
    if cv2.waitKey(5)&0xFF==27:
        break
cap.release()   
cv2.destroyAllWindows()

# %%
import os

image_directory = r"C:\Users\Abhijeet Tripathi\Desktop\new_images"  # Replace with the actual path to your image directory

# Get a list of image files
image_files = [f for f in os.listdir(image_directory) if os.path.isfile(os.path.join(image_directory, f)) and f.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]

# Iterate through each image file
for image_file in image_files:
    image_name = os.path.splitext(image_file)[0]  # Extract the image name without extension
    txt_file = image_name + ".txt"  # Assume the corresponding text file has the same name with .txt extension

    # Check if the corresponding text file exists
    if not os.path.exists(os.path.join(image_directory, txt_file)):
        # Delete the image file if the corresponding text file does not exist
        os.remove(os.path.join(image_directory, image_file))
        print(f"Deleted {image_file} because {txt_file} does not exist.")
# Out:
# Deleted new_image_0.jpg because new_image_0.txt does not exist.
# Deleted new_image_10.jpg because new_image_10.txt does not exist.
# Deleted new_image_100.jpg because new_image_100.txt does not exist.
# Deleted new_image_101.jpg because new_image_101.txt does not exist.
# Deleted new_image_102.jpg because new_image_102.txt does not exist.
# Deleted new_image_103.jpg because new_image_103.txt does not exist.
# Deleted new_image_104.jpg because new_image_104.txt does not exist.
# Deleted new_image_105.jpg because new_image_105.txt does not exist.
# Deleted new_image_11.jpg because new_image_11.txt does not exist.
# Deleted new_image_12.jpg because new_image_12.txt does not exist.
# Deleted new_image_13.jpg because new_image_13.txt does not exist.
# Deleted new_image_14.jpg because new_image_14.txt does not exist.
# Deleted new_image_15.jpg because new_image_15.txt does not exist.
# Deleted new_image_16.jpg because new_image_16.txt does not exist.
# Deleted new_image_17.jpg because new_image_17.txt does not exist.
# Deleted new_image_18.jpg because new_image_18.txt does not exist.
# Deleted new_image_19.jpg because new_image_19.txt does not exist.
# Deleted new_image_20.jpg because new_image_20.txt does not exist.
# Deleted new_image_21.jpg because new_image_21.txt does not exist.
# Deleted new_image_219.jpg because new_image_219.txt does not exist.
# Deleted new_image_22.jpg because new_image_22.txt does not exist.
# Deleted new_image_231.jpg because new_image_231.txt does not exist.
# Deleted new_image_31.jpg because new_image_31.txt does not exist.
# Deleted new_image_32.jpg because new_image_32.txt does not exist.
# Deleted new_image_33.jpg because new_image_33.txt does not exist.
# Deleted new_image_34.jpg because new_image_34.txt does not exist.
# Deleted new_image_35.jpg because new_image_35.txt does not exist.
# Deleted new_image_36.jpg because new_image_36.txt does not exist.
# Deleted new_image_37.jpg because new_image_37.txt does not exist.
# Deleted new_image_47.jpg because new_image_47.txt does not exist.
# Deleted new_image_48.jpg because new_image_48.txt does not exist.
# Deleted new_image_49.jpg because new_image_49.txt does not exist.
# Deleted new_image_50.jpg because new_image_50.txt does not exist.
# Deleted new_image_51.jpg because new_image_51.txt does not exist.
# Deleted new_image_52.jpg because new_image_52.txt does not exist.
# Deleted new_image_53.jpg because new_image_53.txt does not exist.
# Deleted new_image_54.jpg because new_image_54.txt does not exist.
# Deleted new_image_55.jpg because new_image_55.txt does not exist.
# Deleted new_image_56.jpg because new_image_56.txt does not exist.
# Deleted new_image_57.jpg because new_image_57.txt does not exist.
# Deleted new_image_58.jpg because new_image_58.txt does not exist.
# Deleted new_image_72.jpg because new_image_72.txt does not exist.
# Deleted new_image_73.jpg because new_image_73.txt does not exist.
# Deleted new_image_74.jpg because new_image_74.txt does not exist.
# Deleted new_image_75.jpg because new_image_75.txt does not exist.
# Deleted new_image_76.jpg because new_image_76.txt does not exist.
# Deleted new_image_77.jpg because new_image_77.txt does not exist.
# Deleted new_image_78.jpg because new_image_78.txt does not exist.
# Deleted new_image_79.jpg because new_image_79.txt does not exist.
# Deleted new_image_80.jpg because new_image_80.txt does not exist.
# Deleted new_image_81.jpg because new_image_81.txt does not exist.
# Deleted new_image_82.jpg because new_image_82.txt does not exist.
# Deleted new_image_83.jpg because new_image_83.txt does not exist.
# Deleted new_image_84.jpg because new_image_84.txt does not exist.
# Deleted new_image_85.jpg because new_image_85.txt does not exist.
# Deleted new_image_86.jpg because new_image_86.txt does not exist.
# Deleted new_image_87.jpg because new_image_87.txt does not exist.
# Deleted new_image_88.jpg because new_image_88.txt does not exist.
# Deleted new_image_89.jpg because new_image_89.txt does not exist.
# Deleted new_image_9.jpg because new_image_9.txt does not exist.
# Deleted new_image_90.jpg because new_image_90.txt does not exist.
# Deleted new_image_91.jpg because new_image_91.txt does not exist.
# Deleted new_image_92.jpg because new_image_92.txt does not exist.
# Deleted new_image_93.jpg because new_image_93.txt does not exist.
# Deleted new_image_94.jpg because new_image_94.txt does not exist.
# Deleted new_image_95.jpg because new_image_95.txt does not exist.
# Deleted new_image_96.jpg because new_image_96.txt does not exist.
# Deleted new_image_97.jpg because new_image_97.txt does not exist.
# Deleted new_image_98.jpg because new_image_98.txt does not exist.
# Deleted new_image_99.jpg because new_image_99.txt does not exist.
